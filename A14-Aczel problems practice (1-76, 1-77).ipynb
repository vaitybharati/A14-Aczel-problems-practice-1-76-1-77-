# %% [markdown]
# # A14-Aczel problems practice (1-76, 1-77)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### 76. The following table shows changes in bad loans and in provisions for bad loans, from 2005 to 2006, for 19 lending institutions. Verify the reported averages, and find the medians. Which measure is more meaningful, in your opinion? Also find the standard deviation and identify outliers for change in bad loans and change in provision for bad loans.
#
# ![image.png](attachment:image.png)

# %%
cbl=pd.Series([16.8,91.7,24.5,123.5,42.3,19.7,15.2,55.1,44.9,96.5,45.5,116.9,79.2,22.9,17.3,17.6,43.4,37.2,159.1])

# %%
cpbl=pd.Series([12.1,23.3,-2.8,4.4,-12,3.6,12,-4.5,1.9,15.6,13.8,25.4,14,1.4,8.9,8.6,0,-8.7,37.3])

# %%
# verify reported avgs

# %%
cbl.mean() # reported avg is different
# Out:
# 56.27894736842105

# %%
cpbl.mean() # reported avg is different
# Out:
# 8.121052631578948

# %%
# Find Medians

# %%
cbl.median()
# Out:
# 43.4

# %%
cpbl.median()
# Out:
# 8.6

# %% [raw]
# # Which measure is more meaningful
# -> Median is more meaningful than mean here, as existance of outliars can give different means

# %%
# Standard deviation

# %%
cbl.std()
# Out:
# 42.726137966086704

# %%
cpbl.std()
# Out:
# 12.21408926642454

# %%
# Outliars

# %%
plt.boxplot(cbl) # No Outliars
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2afb43b2d00>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2afad6f0400>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2afb43b29a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2afad6f0ac0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2afad6f0dc0>],
#  'means': []}

# %%
plt.boxplot(cpbl) # One Outuliar
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2afa95a5340>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2afa95a5a00>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2afa9597fa0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2afa95af100>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2afa95af400>],
#  'means': []}

# %% [markdown]
# #### 77. Repeat problem 1–76 for the bank assets data, shown in parentheses in the table at the bottom of the previous page.

# %%
ba=pd.Series([1459,707.1,481.9,182.2,103.4,100.7,60.7,58,57,56.2,45.3,40.2,37.9,35.3,34.2,31.9,21,17.72,17.2])

# %%
# verify reported avgs

# %%
ba.mean() # reported avg is different
# Out:
# 186.67999999999995

# %%
# Find Median

# %%
ba.median()
# Out:
# 56.2

# %% [raw]
# # Which measure is more meaningful
# -> Median is more meaningful than mean here as existance of outliars can give different means

# %%
# Standard deviation

# %%
ba.std()
# Out:
# 355.57727186459306

# %%
# Outliars

# %%
plt.boxplot(ba) # 3 outliars
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1637fdee850>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1637fdeef10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1637fdee4f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1637fe06610>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1637fe06910>],
#  'means': []}
